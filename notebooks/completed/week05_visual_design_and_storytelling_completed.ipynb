# %% [markdown]
# # Week 5 — Visual Design and Storytelling
#
# **Business question.** How do we turn a correct chart into a persuasive one?
#
# *Datasets:* `sales`  ·  *Run `uv run python scripts/fetch_data.py` first if you have not.*

# %% [markdown]
# ## Learning objectives
#
# By the end of this session you should be able to:
#
# - Apply decluttering: remove non-data ink.
# - Use colour to direct attention to one message.
# - Annotate a chart so it states its own conclusion.
# - Redesign a default chart into a story chart.

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from dataviz_course import load, save_figure, set_house_style

set_house_style()

# %% [markdown]
# ## From correct to compelling
#
# A chart can be accurate yet say nothing. Storytelling design means: a title that states the *takeaway* (not just the variable), colour that **highlights one thing** and greys the rest, direct labels instead of legends, and the removal of gridlines and borders that compete with the data.

# %% [markdown]
# ## Load the data

# %%
sales = load("sales")
by_region = sales.groupby("region")["revenue"].sum().sort_values()
by_region

# %% [markdown]
# ### The default chart
#
# Here is the chart most people would produce: technically fine, but it makes the reader do the work.

# %%
fig, ax = plt.subplots()
by_region.plot(kind="bar", ax=ax, color="#4C72B0")
ax.set_title("Revenue by region")
ax.tick_params(axis="x", rotation=0)
plt.show()

# %% [markdown]
# ### The redesigned story chart
#
# Sort, switch to horizontal bars, grey everything except the leader, label the values directly, and write the conclusion in the title.

# %%
leader = by_region.idxmax()
colors = ["#C44E52" if r == leader else "#B0B0B0" for r in by_region.index]

fig, ax = plt.subplots()
bars = ax.barh(by_region.index, by_region.values, color=colors)
for bar, value in zip(bars, by_region.values, strict=True):
    ax.text(value, bar.get_y() + bar.get_height() / 2, f"  €{value:,.0f}",
            va="center", fontsize=9)
ax.set_title(f"{leader} is our top-earning region")
ax.set_xlabel("Total revenue (€)")
ax.margins(x=0.18)
save_figure(fig, "week05_story_chart")
plt.show()

# %% [markdown]
# ## Pause and predict
#
# Cover the titles. Which version lets a busy executive get the message in two seconds? What exactly did the redesign change — and did any of it distort the data?

# %% [markdown]
# ## Common mistakes
#
# - **Rainbow colour.** Giving every bar its own colour signals 'all equally important' — the opposite of a story.
# - **Title that names the axis.** 'Revenue by region' wastes the most-read text; state the finding instead.
# - **Decoration over clarity.** 3-D bars, shadows, and heavy gridlines add ink, not information.

# %% [markdown]
# ## AI co-pilot activity
#
# Ask an AI assistant: *"Restyle a matplotlib bar chart to highlight a single category and grey the rest"* Paste its code into a new cell and run it.
#
# Then **do not trust it yet** — work through the verification checklist below before you keep it.

# %% [markdown]
# ## Verification checklist for AI output
#
# Before relying on any chart or code an assistant gives you, confirm:
#
# 1. Does the chart actually answer *which region leads and by how much*?
# 2. Are the axes, units, and scale correct and honest?
# 3. Is this the right chart type for the data?
# 4. Did the code run on **our** dataset (correct columns, no invented data)?
# 5. Were rows silently dropped, duplicated, or mis-aggregated?
# 6. Could the colour, ordering, or missing context mislead a reader?
#
# If you cannot answer all six, fix it before moving on.

# %% [markdown]
# ## Exercises
#
# 1. Redesign the weekly revenue line from Week 1 to highlight the holiday peak with an annotation.
# 2. Take the channel bar chart and apply the grey-plus-highlight treatment to the Online channel.
# 3. Write three alternative takeaway titles for the region chart, each emphasising a different message.
