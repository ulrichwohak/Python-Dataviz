# %% [markdown]
# # Week 1 — Introduction to Visualisation
#
# **Business question.** Is our business growing, and where does the revenue come from?
#
# *Datasets:* `sales`  ·  *Run `uv run python scripts/fetch_data.py` first if you have not.*

# %% [markdown]
# ## Learning objectives
#
# By the end of this session you should be able to:
#
# - Explain why we visualise data instead of reading tables.
# - Identify the anatomy of a chart (axes, marks, encodings, labels).
# - Build a first line chart and bar chart with matplotlib.
# - Choose between a line and a bar chart for a given question.

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from dataviz_course import load, save_figure, set_house_style

set_house_style()

# %% [markdown]
# ## Why visualise?
#
# A table of 7,000 weekly sales rows hides the story; a single line shows the trend at a glance. Every chart **encodes** data values as visual properties — position, length, colour. Good charts pick encodings the eye reads accurately: *position* and *length* are read best, which is why lines and bars dominate business reporting.

# %% [markdown]
# ## Load the data

# %%
sales = load("sales")
sales.head()

# %% [markdown]
# ### A line chart for trend over time
#
# We sum revenue across all regions and channels to one number per week, then plot it over time. **Position** along the x-axis encodes time; position on the y-axis encodes revenue.

# %%
weekly = sales.groupby("date", as_index=False)["revenue"].sum()

fig, ax = plt.subplots()
ax.plot(weekly["date"], weekly["revenue"], color="#4C72B0")
ax.set_title("Total weekly revenue is trending up")
ax.set_xlabel("Week")
ax.set_ylabel("Revenue (€)")
fig.autofmt_xdate()
plt.show()

# %% [markdown]
# ### A bar chart for comparing categories
#
# To compare *categories* (regions) rather than a trend, length-encoded bars are clearer than a line. We sort the bars so the ranking is obvious, and save the figure to `figures/`.

# %%
by_region = sales.groupby("region")["revenue"].sum().sort_values()

fig, ax = plt.subplots()
ax.barh(by_region.index, by_region.values, color="#4C72B0")
ax.set_title("Total revenue by region")
ax.set_xlabel("Revenue (€)")
save_figure(fig, "week01_revenue_by_region")
plt.show()

# %% [markdown]
# ## Pause and predict
#
# Before running the next cell, predict: which region will have the **highest** total revenue, and roughly how does the weekly line behave near the end of each year? Write your guess down, then check it against the charts above.

# %% [markdown]
# ## Common mistakes
#
# - **Unsorted bars.** Leaving regions in data order makes the ranking hard to read — always sort categorical bars by value.
# - **Truncated y-axis.** Starting a bar chart's axis above zero exaggerates differences.
# - **Line chart for unordered categories.** A line implies continuity; never use one to compare regions.

# %% [markdown]
# ## AI co-pilot activity
#
# Ask an AI assistant: *"Plot total revenue by product_category from a pandas DataFrame called sales"* Paste its code into a new cell and run it.
#
# Then **do not trust it yet** — work through the verification checklist below before you keep it.

# %% [markdown]
# ## Verification checklist for AI output
#
# Before relying on any chart or code an assistant gives you, confirm:
#
# 1. Does the chart actually answer *is the business growing, and where does revenue come from*?
# 2. Are the axes, units, and scale correct and honest?
# 3. Is this the right chart type for the data?
# 4. Did the code run on **our** dataset (correct columns, no invented data)?
# 5. Were rows silently dropped, duplicated, or mis-aggregated?
# 6. Could the colour, ordering, or missing context mislead a reader?
#
# If you cannot answer all six, fix it before moving on.

# %% [markdown]
# ## Exercises
#
# 1. Plot total weekly `units_sold` over time. How does its shape compare to the revenue line?
# 2. Make a sorted bar chart of total revenue by `channel`. Which channel leads?
# 3. The revenue line is noisy. Add a 4-week rolling mean as a second line and label both.
