# %% [markdown]
# # Week 3 — Core Business Charts — Exercises
#
# **Business question.** How do channels and regions contribute to revenue over time?
#
# *Datasets:* `sales`  ·  *Run `uv run python scripts/fetch_data.py` first if you have not.*

# %% [markdown]
# ## Learning objectives
#
# By the end of this session you should be able to:
#
# - Build multi-series line charts for time trends.
# - Compare groups with grouped and stacked bar charts.
# - Know when stacking helps and when it misleads.
# - Use small multiples to compare many series fairly.

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from dataviz_course import load, save_figure, set_house_style

set_house_style()

# %%
sales = load("sales")
sales = sales.dropna(subset=["revenue"])
sales.head()

# %% [markdown]
# ### Exercise 1
#
# Re-make the channel line chart as `units_sold` instead of revenue. Does the channel ranking change?

# %%
# Your answer here

# %% [markdown]
# ### Exercise 2
#
# Build a grouped bar of revenue by `product_category` and `channel`.

# %%
# Your answer here

# %% [markdown]
# ### Exercise 3
#
# Add the `campaign_indicator` as a colour to the monthly line and see if campaign weeks stand out.

# %%
# Your answer here
