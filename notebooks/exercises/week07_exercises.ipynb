# %% [markdown]
# # Week 7 — Interactive Visualisation and Dashboards — Exercises
#
# **Business question.** How do we let stakeholders explore the numbers themselves?
#
# *Datasets:* `dashboard`  ·  *Run `uv run python scripts/fetch_data.py` first if you have not.*

# %% [markdown]
# ## Learning objectives
#
# By the end of this session you should be able to:
#
# - Build interactive charts with plotly express.
# - Add hover, zoom, and legend filtering for exploration.
# - Understand when interactivity helps and when it distracts.
# - See how a notebook chart becomes a Streamlit dashboard.

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from dataviz_course import load, save_figure, set_house_style

set_house_style()

# %%
dash = load("dashboard")
dash.head()

# %% [markdown]
# ### Exercise 1
#
# Make a plotly line of revenue by `month` and `channel` (use `color='channel'`).

# %%
# Your answer here

# %% [markdown]
# ### Exercise 2
#
# Add `units_sold` as the bar height and `revenue` as hover data to the region bar.

# %%
# Your answer here

# %% [markdown]
# ### Exercise 3
#
# Open `dashboards/app.py`, run it with `uv run streamlit run dashboards/app.py`, and add one new filter.

# %%
# Your answer here
