# %% [markdown]
# # Week 6 — Geospatial Visualisation — Exercises
#
# **Business question.** Which regions punch above their weight in sales per capita?
#
# *Datasets:* `regions`, `stores`  ·  *Run `uv run python scripts/fetch_data.py` first if you have not.*

# %% [markdown]
# ## Learning objectives
#
# By the end of this session you should be able to:
#
# - Load vector geometries with geopandas.
# - Build a choropleth and read its classification.
# - Understand CRS and why we reproject before measuring area.
# - Overlay point data (stores) on a region map.

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from dataviz_course import load, save_figure, set_house_style

set_house_style()

# %%
regions = load("regions")
stores = load("stores")
regions[["region_name", "population", "sales_per_capita"]]

# %% [markdown]
# ### Exercise 1
#
# Make a choropleth of `average_income` instead of sales per capita. Does the pattern match?

# %%
# Your answer here

# %% [markdown]
# ### Exercise 2
#
# Count the number of stores per region (spatial or attribute join) and add it as a label.

# %%
# Your answer here

# %% [markdown]
# ### Exercise 3
#
# Colour the store points by their `region_id` instead of sizing them by revenue.

# %%
# Your answer here
