# %% [markdown]
# # Week 2 — Data for Visualisation — Exercises
#
# **Business question.** How do we reshape raw transactions into something we can chart?
#
# *Datasets:* `transactions`, `customers`  ·  *Run `uv run python scripts/fetch_data.py` first if you have not.*

# %% [markdown]
# ## Learning objectives
#
# By the end of this session you should be able to:
#
# - Describe tidy data and why charting libraries expect it.
# - Aggregate and reshape with groupby and pivot_table.
# - Detect and handle missing values before plotting.
# - Turn a transaction log into a monthly category trend.

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from dataviz_course import load, save_figure, set_house_style

set_house_style()

# %%
transactions = load("transactions")
customers = load("customers")
transactions.head()

# %% [markdown]
# ### Exercise 1
#
# Build a month × `channel` pivot of total revenue and plot it. (Hint: join `customers` to get each transaction's region or channel if needed, or use `product_category`.)

# %%
# Your answer here

# %% [markdown]
# ### Exercise 2
#
# Compute the share of revenue that comes with a non-zero `discount`. Visualise it.

# %%
# Your answer here

# %% [markdown]
# ### Exercise 3
#
# Replace missing `income` with the segment median instead of dropping it. Does the histogram change?

# %%
# Your answer here
