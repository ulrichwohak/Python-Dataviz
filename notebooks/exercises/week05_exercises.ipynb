# %% [markdown]
# # Week 5 — Visual Design and Storytelling — Exercises
#
# **Business question.** How do we turn a correct chart into a persuasive one?
#
# *Datasets:* `sales`  ·  *Run `uv run python scripts/fetch_data.py` first if you have not.*

# %% [markdown]
# ## Learning objectives
#
# By the end of this session you should be able to:
#
# - Apply decluttering: remove non-data ink.
# - Use colour to direct attention to one message.
# - Annotate a chart so it states its own conclusion.
# - Redesign a default chart into a story chart.

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from dataviz_course import load, save_figure, set_house_style

set_house_style()

# %%
sales = load("sales")
by_region = sales.groupby("region")["revenue"].sum().sort_values()
by_region

# %% [markdown]
# ### Exercise 1
#
# Redesign the weekly revenue line from Week 1 to highlight the holiday peak with an annotation.

# %%
# Your answer here

# %% [markdown]
# ### Exercise 2
#
# Take the channel bar chart and apply the grey-plus-highlight treatment to the Online channel.

# %%
# Your answer here

# %% [markdown]
# ### Exercise 3
#
# Write three alternative takeaway titles for the region chart, each emphasising a different message.

# %%
# Your answer here
