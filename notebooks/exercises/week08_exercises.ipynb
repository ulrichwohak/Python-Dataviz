# %% [markdown]
# # Week 8 — Project Workshop and Peer Review — Exercises
#
# **Business question.** Can you carry one question from data to a polished, honest chart?
#
# *Datasets:* `customers`  ·  *Run `uv run python scripts/fetch_data.py` first if you have not.*

# %% [markdown]
# ## Learning objectives
#
# By the end of this session you should be able to:
#
# - Run the full workflow end to end on a fresh question.
# - Produce one decision-ready chart with a takeaway title.
# - Apply the verification checklist to your own work.
# - Give and receive structured peer feedback.

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from dataviz_course import load, save_figure, set_house_style

set_house_style()

# %%
customers = load("customers")
segment_summary = (customers.groupby("segment", as_index=False)
                   .agg(customers=("customer_id", "count"),
                        avg_clv=("customer_lifetime_value", "mean"),
                        avg_churn=("churn_probability", "mean")))
segment_summary

# %% [markdown]
# ### Exercise 1
#
# Add segment size as a second panel (or a secondary annotation) so the CLV chart is not read in isolation.

# %%
# Your answer here

# %% [markdown]
# ### Exercise 2
#
# Pick a different question from any dataset and produce one decision-ready chart for it.

# %%
# Your answer here

# %% [markdown]
# ### Exercise 3
#
# Swap charts with a peer and complete the peer-review rubric on theirs.

# %%
# Your answer here
